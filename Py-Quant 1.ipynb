# %% [markdown]
# ## Numerical Programming

# %%
import numpy as np
a = np.linspace(-np.pi, np.pi, 100)
b = np.cos(a)
c = np.ones(25)
np.dot(c, c)
# Out:
# 25.0

# %% [markdown]
#  ## Using Scipy |

# %%
from scipy.stats import norm
from scipy.integrate import quad
phi = norm()
value, error = quad(phi.pdf, -2,2)
value
# Out:
# 0.9544997361036417

# %% [markdown]
# ## Symbolic Algebra

# %%
from sympy import Symbol
x, y = Symbol('x'), Symbol('y')
x + x + x + y
# Out:
# 3*x + y

# %%
expression = (x + y)**2
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
from sympy import solve
solve(x**2 + x + 2)
# Out:
# [-1/2 - sqrt(7)*I/2, -1/2 + sqrt(7)*I/2]

# %%
from sympy import limit, sin, diff
limit(1 / x, x, 0)
# Out:
# oo

# %%
limit(sin(x)/ x, x, 0)
# Out:
# 1

# %%
diff(sin(x), x)
# Out:
# cos(x)

# %% [markdown]
# ## Statistics & Pandas

# %%
import pandas as pd
import scipy as sp
data = sp.rand(5, 2) # create 5 x 2 matric of rands 
dates = pd.date_range('28/12/2010', periods=5)
df = pd.DataFrame(data, columns=('price', 'weight'), index=dates)

# %%
df
# Out:
#                price    weight
# 2010-12-28  0.445106  0.094537
# 2010-12-29  0.756441  0.140441
# 2010-12-30  0.411632  0.471963
# 2010-12-31  0.766312  0.792417
# 2011-01-01  0.780840  0.666580

# %%
df.mean()
# Out:
# price     0.632066
# weight    0.433188
# dtype: float64

# %% [markdown]
# ## Networks and Graphs

# %%
import networkx as nx 
import matplotlib.pyplot as plt
import numpy as np

G = nx.random_geometric_graph(200, 0.12) # generate random graph
pos = nx.get_node_attributes(G, 'pos')
# find node nearest the center point (0,5,0.5)
dists = [(x - 0.5)**2 + (y - 0.5)**2 for x, y in list(pos.values())]
ncenter = np.argmin(dists)
# Plot graph, coloring by path length from central node
p = nx.single_source_shortest_path_length(G, ncenter)
plt.figure()
nx.draw_networkx_edges(G, pos, alpha=0.4)
nx.draw_networkx_nodes(G, pos, nodelist=list(p.keys()),
                       node_size=120, alpha=0.5,
                       node_color=list(p.values()), cmap=plt.cm.jet_r)
plt.show()

# %% [markdown]
# ##Cloud Computing
#     #Wakari
#     #Amazon Elastic Compute Cloud
#     #Google App Engine
#     #Pythonanywhere
#     #Sagemath Cloud
#
# ##Parallel Processing
