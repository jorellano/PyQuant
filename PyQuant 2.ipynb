# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# use custom colors and opacity

for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)

# %%
plt.show()

# %% [markdown]
# ## Eigen Values + Eigen Vector

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import eig

A = ((1, 2),
     (2, 1))
A = np.array(A)
evals, evecs = eig(A)
evecs = evecs[:, 0], evecs[:, 1]

fig, ax = plt.subplots()
# Set the axes through the origin
for spine in ['left', 'bottom']:
    ax.spines[spine].set_position('zero')
for spine in ['right', 'top']:
    ax.spines[spine].set_color('none')
ax.grid(alpha=0.4)

xmin, xmax = -3, 3
ymin, ymax = -3, 3
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
# ax.set_xticks(())
# ax.set_yticks(())

# Plot each eigenvector
for v in evecs:
    ax.annotate('', xy=v, xytext=(0, 0),
                arrowprops=dict(facecolor='blue',
                shrink=0,
                alpha=0.6,
                width=0.5))

# Plot the image of each eigenvector
for v in evecs:
    v = np.dot(A, v)
    ax.annotate('', xy=v, xytext=(0, 0),
                arrowprops=dict(facecolor='red',
                shrink=0,
                alpha=0.6,
                width=0.5))

# Plot the lines they run through
x = np.linspace(xmin, xmax, 3)
for v in evecs:
    a = v[1] / v[0]
    ax.plot(x, a * x, 'b-', lw=0.4)


plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\ElPanda\\OneDrive\\PyQuant'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA6E-4B74
#
#  Directory of C:\Users\ElPanda\OneDrive\PyQuant
#
# 08/24/2016  09:36 PM    <DIR>          .
# 08/24/2016  09:36 PM    <DIR>          ..
# 08/24/2016  08:42 PM    <DIR>          .ipynb_checkpoints
# 08/24/2016  08:27 PM           114,932 Py-Quant 1.ipynb
# 08/24/2016  09:36 PM            81,594 PyQuant 2.ipynb
#                2 File(s)        196,526 bytes
#                3 Dir(s)  184,706,940,928 bytes free

# %%
cd
# Out:
# C:\Users\ElPanda

# %%
cd onedrive
# Out:
# C:\Users\ElPanda\onedrive

# %%
dir
# Out:
# <function dir>

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA6E-4B74
#
#  Directory of C:\Users\ElPanda\onedrive
#
# 08/24/2016  08:41 PM    <DIR>          .
# 08/24/2016  08:41 PM    <DIR>          ..
# 08/18/2016  07:29 PM    <DIR>          .ipynb_checkpoints
# 06/21/2015  03:27 PM               165 ~$WSR 62015.xlsx
# 06/29/2016  04:50 PM           228,561 2014-2016%20Parkside%20Dr.xlsx
# 08/03/2016  09:01 AM    <DIR>          9gag
# 07/29/2016  12:18 PM    <DIR>          Bill of sale
# 06/28/2016  03:17 PM             8,137 binning.ipynb
# 06/08/2016  09:12 PM    <DIR>          Bucket + quick release
# 07/14/2016  01:49 PM    <DIR>          Craigslist
# 07/06/2016  06:36 PM    <DIR>          Documents
# 06/02/2016  01:37 PM    <DIR>          Ebay
# 03/03/2016  08:51 PM    <DIR>          HAPPY_ANNIVERSARY
# 08/17/2016  10:10 PM    <DIR>          javascript
# 08/17/2016  10:11 PM    <DIR>          L_Python
# 08/24/2016  08:41 PM    <DIR>          Lending Club
# 07/07/2016  10:53 AM    <DIR>          MWLANG
# 05/16/2016  10:10 PM    <DIR>          Pictures
# 08/24/2016  09:42 PM    <DIR>          PyQuant
# 06/29/2016  05:10 PM            25,449 R 2014-2016 Parkside Dr.ods
# 05/17/2016  09:40 PM    <DIR>          R data
# 06/19/2016  07:09 PM           593,053 reg343.pdf
# 06/19/2016  07:07 PM           593,053 reg343-2.pdf
# 06/19/2016  09:32 PM           593,053 regis.pdf
# 07/18/2016  11:18 PM    <DIR>          Resume
# 06/11/2016  09:56 PM            14,939 svm practice.ipynb
# 07/21/2016  08:20 PM    <DIR>          Untitled Folder
# 08/18/2016  07:33 PM             8,394 Untitled.ipynb
#                9 File(s)      2,064,804 bytes
#               19 Dir(s)  184,707,739,648 bytes free

# %%
cd pyquant
# Out:
# C:\Users\ElPanda\onedrive\pyquant

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA6E-4B74
#
#  Directory of C:\Users\ElPanda\onedrive\pyquant
#
# 08/24/2016  09:42 PM    <DIR>          .
# 08/24/2016  09:42 PM    <DIR>          ..
# 08/24/2016  08:42 PM    <DIR>          .ipynb_checkpoints
# 08/24/2016  08:27 PM           114,932 Py-Quant 1.ipynb
# 08/24/2016  09:42 PM            84,268 PyQuant 2.ipynb
#                2 File(s)        199,200 bytes
#                3 Dir(s)  184,707,674,112 bytes free

# %% [markdown]
# ## Plotting White Noise

# %%
from random import normalvariate
import matplotlib.pyplot as plt
ts_length = 100
epsilon_values = []

for i in range(ts_length):
    e = normalvariate(0,1)
    epsilon_values.append(e)
plt.plot(epsilon_values, 'b-')
plt.show()

# %%
from random import normalvariate, uniform
normalvariate(0, 1)
# Out:
# -0.09698484942891093

# %%
uniform(-1, 1)
# Out:
# 0.496933414635335

# %%
import random
random.normalvariate(0, 1)
# Out:
# 1.651431279450788

# %%
random.uniform(-1, 1)
# Out:
# -0.6839487581522665

# %%
x = [10, 'foo', False]
type(x)
# Out:
# list

# %%
x
# Out:
# [10, 'foo', False]

# %%
x.append(2.5)

# %%
x
# Out:
# [10, 'foo', False, 2.5]
